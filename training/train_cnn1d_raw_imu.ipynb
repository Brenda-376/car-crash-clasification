# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import joblib
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.layers import Conv1D, Dense, Dropout, GlobalAveragePooling1D, Input, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from timeit import default_timer as timer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = pd.read_csv('../dataset/imu_dataset.csv')
df
# Out:
#         subject        class  scenario      timestamp       accX      accY  \
# 0      subject1       normal         0  1733143133217    2.50347   0.92154
# 1      subject1       normal         0  1733143133267    2.91587  -0.10845
# 2      subject1       normal         0  1733143133316    2.09685   0.23087
# 3      subject1       normal         0  1733143133368    3.55718  -1.27921
# 4      subject1       normal         0  1733143133417    4.75269   0.79279
# ...         ...          ...       ...            ...        ...       ...
# 31355  subject1  minor_crash       210  1733918402058   46.09508  -5.42834
# 31356  subject1  minor_crash       210  1733918402105  -25.19053  11.36514
# 31357  subject1  minor_crash       210  1733918402159   53.45271 -29.42361
# 31358  subject1  minor_crash       210  1733918402209 -178.79508  49.69384
# 31359  subject1  minor_crash       210  1733918402260  193.89269 -36.99012
#
#             accZ     gyrX     gyrY     gyrZ
# 0        0.53716 -0.01380  0.01094 -0.00061
# 1        0.24650 -0.01153  0.00783  0.00070
# 2        0.22614 -0.00326 -0.00018  0.00286
# 3        0.47487  0.00114  0.00148  0.00002
# 4       -1.20326 -0.00456  0.00749 -0.00368
# ...          ...      ...      ...      ...
# 31355  -34.29297  0.05467 -0.09112  0.04304
# 31356   17.44765  0.01944 -0.09596  0.06311
# 31357  -80.25206  0.02057 -0.00703 -0.09909
# 31358  172.22260 -0.06077 -0.05234 -0.00718
# 31359 -175.94617  0.06537  0.05832 -0.07686
#
# [31360 rows x 10 columns]

# %%
print('Number of columns in the dataframe: %i' % (df.shape[1]))
print('Number of rows in the dataframe: %i\n' % (df.shape[0]))
# Out:
# Number of columns in the dataframe: 10
# Number of rows in the dataframe: 31360

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31360 entries, 0 to 31359
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    31360 non-null  object
#  1   class      31360 non-null  object
#  2   scenario   31360 non-null  int64
#  3   timestamp  31360 non-null  int64
#  4   accX       31360 non-null  float64
#  5   accY       31360 non-null  float64
#  6   accZ       31360 non-null  float64
#  7   gyrX       31360 non-null  float64
#  8   gyrY       31360 non-null  float64
#  9   gyrZ       31360 non-null  float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#            scenario     timestamp          accX          accY          accZ  \
# count  31360.000000  3.136000e+04  31360.000000  31360.000000  31360.000000
# mean      85.558036  1.733590e+12     -0.595469     -1.049940     -2.459397
# std       64.413435  3.563225e+08    242.044748    153.432532    478.596020
# min        0.000000  1.733143e+12 -11816.310190  -9961.782770 -27984.889280
# 25%       24.000000  1.733161e+12     -3.637582     -2.827215     -2.566432
# 50%       77.000000  1.733839e+12      0.075390     -0.063020      0.001420
# 75%      142.000000  1.733903e+12      3.712333      2.309317      2.528955
# max      210.000000  1.733918e+12   8847.789770   8468.577300  18435.771400
#
#                gyrX          gyrY          gyrZ
# count  31360.000000  31360.000000  31360.000000
# mean       0.010117     -0.008181      0.009863
# std        0.267849      0.265273      0.657089
# min       -8.997320     -4.819830    -21.060510
# 25%       -0.019040     -0.021420     -0.017862
# 50%        0.000020     -0.000040      0.000010
# 75%        0.019870      0.018240      0.021612
# max        6.089580      6.463000     14.051690

# %%
df.isnull().sum()
# Out:
# subject      0
# class        0
# scenario     0
# timestamp    0
# accX         0
# accY         0
# accZ         0
# gyrX         0
# gyrY         0
# gyrZ         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['class'].unique()
# Out:
# array(['normal', 'severe_crash', 'minor_crash'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# minor_crash     12660
# severe_crash    12300
# normal           6400
# Name: class, dtype: int64

# %%
plt.figure(figsize=(16.5, 5.5))
plt.title('Original Data by Crash Type')
sns.countplot(data=df, x='class', order=df["class"].value_counts().index, palette = sns.color_palette("rocket"))
plt.show()

# %%
df['class'].value_counts().plot(kind='bar',
                                   title='Original Data by Crash Type')
plt.show()

# %%
df['subject'].value_counts().plot(kind='bar',
                                  title='Training Examples by User')
plt.show()

# %%
print(f"Total subjects in the experiment: {len(set(df['subject']))}\n")
print(set(df['subject']))
# Out:
# Total subjects in the experiment: 1
#
# {'subject1'}

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df['accX'] = df['accX'].astype('float')
df['accY'] = df['accY'].astype('float')
df['accZ'] = df['accZ'].astype('float')

df['gyrX'] = df['gyrX'].astype('float')
df['gyrY'] = df['gyrY'].astype('float')
df['gyrZ'] = df['gyrZ'].astype('float')

# %%
Fs = 20
activities = np.unique(df['class']) # or use: activities = data['class'].value_counts().index
activities
# Out:
# array(['minor_crash', 'normal', 'severe_crash'], dtype=object)

# %%
def plot_activity(activity, data):
    fig, axes = plt.subplots(nrows=6, figsize=(12, 10), sharex=True)
    
    # Plot accelerometer data
    plot_axis(axes[0], data['timestamp'], data['accX'], 'Accelerometer X-Axis')
    plot_axis(axes[1], data['timestamp'], data['accY'], 'Accelerometer Y-Axis')
    plot_axis(axes[2], data['timestamp'], data['accZ'], 'Accelerometer Z-Axis')
    
    # Plot gyroscope data
    plot_axis(axes[3], data['timestamp'], data['gyrX'], 'Gyroscope X-Axis')
    plot_axis(axes[4], data['timestamp'], data['gyrY'], 'Gyroscope Y-Axis')
    plot_axis(axes[5], data['timestamp'], data['gyrZ'], 'Gyroscope Z-Axis')
    
    # Adjust layout
    plt.subplots_adjust(hspace=0.4)
    fig.suptitle(activity, fontsize=16)
    plt.subplots_adjust(top=0.9)
    plt.show()

def plot_axis(ax, x, y, title):
    ax.plot(x, y, 'r')
    ax.set_title(title, fontsize=10)
    ax.xaxis.set_visible(False)  # Hide x-axis labels for intermediate plots
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])  # Add buffer to y-axis range
    ax.grid(True)

# Loop through activities and plot
for activity in activities:
    data_for_plot = df[df['class'] == activity][:Fs*4]
    plot_activity(activity, data_for_plot)

# %%
label = LabelEncoder()
df['label'] = label.fit_transform(df['class'])
print(f"Types of classes: {label.classes_}\n")
df
# Out:
# Types of classes: ['minor_crash' 'normal' 'severe_crash']
#         subject        class  scenario      timestamp       accX      accY  \
# 0      subject1       normal         0  1733143133217    2.50347   0.92154
# 1      subject1       normal         0  1733143133267    2.91587  -0.10845
# 2      subject1       normal         0  1733143133316    2.09685   0.23087
# 3      subject1       normal         0  1733143133368    3.55718  -1.27921
# 4      subject1       normal         0  1733143133417    4.75269   0.79279
# ...         ...          ...       ...            ...        ...       ...
# 31355  subject1  minor_crash       210  1733918402058   46.09508  -5.42834
# 31356  subject1  minor_crash       210  1733918402105  -25.19053  11.36514
# 31357  subject1  minor_crash       210  1733918402159   53.45271 -29.42361
# 31358  subject1  minor_crash       210  1733918402209 -178.79508  49.69384
# 31359  subject1  minor_crash       210  1733918402260  193.89269 -36.99012
#
#             accZ     gyrX     gyrY     gyrZ  label
# 0        0.53716 -0.01380  0.01094 -0.00061      1
# 1        0.24650 -0.01153  0.00783  0.00070      1
# 2        0.22614 -0.00326 -0.00018  0.00286      1
# 3        0.47487  0.00114  0.00148  0.00002      1
# 4       -1.20326 -0.00456  0.00749 -0.00368      1
# ...          ...      ...      ...      ...    ...
# 31355  -34.29297  0.05467 -0.09112  0.04304      0
# 31356   17.44765  0.01944 -0.09596  0.06311      0
# 31357  -80.25206  0.02057 -0.00703 -0.09909      0
# 31358  172.22260 -0.06077 -0.05234 -0.00718      0
# 31359 -175.94617  0.06537  0.05832 -0.07686      0
#
# [31360 rows x 11 columns]

# %%
df['label'].value_counts()
# Out:
# 0    12660
# 2    12300
# 1     6400
# Name: label, dtype: int64

# %%
X_train = df.drop(['subject', 'class', 'scenario', 'timestamp', 'label'], axis=1)
y_train = df['label']
scenario_train = df['scenario']

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
joblib.dump(scaler, "scalerIMU_cnn1d_rawData.save")
X_train[0]
# Out:
# array([ 0.01280337,  0.01284937,  0.00626124, -0.08929322,  0.0720803 ,
#        -0.01593857])

# %%
scaled_X = pd.DataFrame(data = X_train, columns = ['accX', 'accY', 'accZ', 'gyrX', 'gyrY', 'gyrZ'])
scaled_X['label'] = y_train.values
scaled_X['scenario'] = scenario_train.values

# %%
# Sampling rate (Hz)
Fs = 20

# Frame size dan hop size berdasarkan sampling rate
frame_size = Fs * 3  # 3 detik (60 sampel)
hop_size = Fs * 1    # 1 detik overlap (20 sampel)

# Fungsi untuk segmentasi berdasarkan skenario
def get_frames_by_scenario(df, frame_size, hop_size):
    N_FEATURES = 6  # accX, accY, accZ, gyrX, gyrY, gyrZ
    frames = []
    labels = []

    # Iterasi per skenario
    for classes in df['label'].unique():
        class_data = df[df['label'] == classes]
        for scenario in class_data['scenario'].unique():
            scenario_data = class_data[class_data['scenario'] == scenario]                
            for i in range(0, len(scenario_data) - frame_size + 1, hop_size):
                segment = scenario_data.iloc[i: i + frame_size]
                features = segment[['accX', 'accY', 'accZ', 'gyrX', 'gyrY', 'gyrZ']].values
                label = stats.mode(segment['label'])[0][0]
                frames.append(features)
                labels.append(label)
    
    # Merapikan format data
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)
    
    return frames, labels

# %%
# Membuat frame untuk data pelatihan dan pengujian
X_train_frames, y_train_frames = get_frames_by_scenario(scaled_X, frame_size, hop_size)
# X_test_frames, y_test_frames = get_frames_by_scenario(test, y_test, frame_size, hop_size)
X_train_frames.shape, y_train_frames.shape
# Out:
# ((672, 60, 6), (672,))

# %%
class_counts = pd.Series(y_train_frames).value_counts()
print(class_counts)
# Out:
# 1    256
# 0    211
# 2    205
# dtype: int64

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_frames, y_train_frames, test_size=0.15, random_state=1337, stratify=y_train_frames)
X_train.shape, X_val.shape
# Out:
# ((571, 60, 6), (101, 60, 6))

# %%
X_train[0].shape, X_val[0].shape
# Out:
# ((60, 6), (60, 6))

# %%
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
# y_test_frames = to_categorical(y_test_frames)
y_train.shape, y_val.shape
# Out:
# ((571, 3), (101, 3))

# %%
model = Sequential([
    Input(shape=X_train[0].shape),
    Conv1D(128, kernel_size=3, strides=1),
    LeakyReLU(alpha=0.05),
    Dropout(0.1),
    Conv1D(256, kernel_size=3, strides=1),
    LeakyReLU(alpha=0.05),
    Dropout(0.1),
    
    GlobalAveragePooling1D(),
    Dense(512),
    LeakyReLU(alpha=0.05),
    Dropout(0.3),
    
    Dense(3, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 58, 128)           2432
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 58, 128)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 58, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 56, 256)           98560
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 56, 256)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 256)           0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 234,115
# Trainable params: 234,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, to_file='architecture_model_cnn1d_rawData.png')

# %%
epochs = 200
lr=1e-4
batch_size = 32

class TimeCallback(Callback):
    def __init__(self):
        self.start_time = None
        self.epoch_time = 0.0
        self.total_time = 0.0
        self.iter_count = 0
    
    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = timer()
    
    def on_epoch_end(self, epoch, logs=None):
        self.epoch_time = timer() - self.start_time
        self.total_time += self.epoch_time
    
    def on_train_batch_end(self, batch, logs=None):
        self.iter_count += 1
    
    def on_train_end(self, logs=None):
        print("\nAverage iteration time: {:.2f} ms".format((self.total_time/self.iter_count) * 1000))
        print("Average epoch time: {:.2f} s".format(self.total_time/epochs))
        print("Total training time: {:.2f} s".format(self.total_time))

# %%
# Creating new directory to store the best model
os.makedirs("./model", exist_ok=True)

# %%
#Optimizer Adam
def get_optimizer():
    return Adam(learning_rate=lr)

#Compiling the model
model.compile(optimizer=get_optimizer(), loss='categorical_crossentropy', metrics=['accuracy'])
checkpoint = ModelCheckpoint("./model/model_imu_cnn1d_rawData.h5", verbose=1)
callback = TimeCallback()

# %%
hist = model.fit(X_train, 
                    y_train,
                    validation_data=(X_val, y_val),
                    batch_size=batch_size,
                    epochs=epochs,
                    callbacks=[callback, checkpoint])
# Out:
# Epoch 1/200
# 18/18 [==============================] - ETA: 0s - loss: 1.0547 - accuracy: 0.4151
# Epoch 00001: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 35ms/step - loss: 1.0547 - accuracy: 0.4151 - val_loss: 1.0286 - val_accuracy: 0.3366
# Epoch 2/200
# 10/18 [===============>..............] - ETA: 0s - loss: 1.0041 - accuracy: 0.3531
# Epoch 00002: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.9898 - accuracy: 0.3660 - val_loss: 0.9918 - val_accuracy: 0.3663
# Epoch 3/200
# 10/18 [===============>..............] - ETA: 0s - loss: 0.9267 - accuracy: 0.4187
# Epoch 00003: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.9565 - accuracy: 0.4133 - val_loss: 0.9697 - val_accuracy: 0.4059
# Epoch 4/200
# 10/18 [===============>..............] - ETA: 0s - loss: 0.9105 - accuracy: 0.4625
# Epoch 00004: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.9326 - accuracy: 0.4483 - val_loss: 0.9519 - val_accuracy: 0.4752
# Epoch 5/200
# 11/18 [=================>............] - ETA: 0s - loss: 0.9310 - accuracy: 0.4716
# Epoch 00005: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.9143 - accuracy: 0.4991 - val_loss: 0.9337 - val_accuracy: 0.4851
# Epoch 6/200
# 17/18 [===========================>..] - ETA: 0s - loss: 0.8951 - accuracy: 0.5257
# Epoch 00006: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.8943 - accuracy: 0.5254 - val_loss: 0.9137 - val_accuracy: 0.5050
# Epoch 7/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.8731 - accuracy: 0.5577
# Epoch 00007: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.8707 - accuracy: 0.5517 - val_loss: 0.8893 - val_accuracy: 0.5545
# Epoch 8/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.8346 - accuracy: 0.5958
# Epoch 00008: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 28ms/step - loss: 0.8437 - accuracy: 0.5867 - val_loss: 0.8631 - val_accuracy: 0.5644
# Epoch 9/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.8160 - accuracy: 0.6082
# Epoch 00009: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.8152 - accuracy: 0.6077 - val_loss: 0.8349 - val_accuracy: 0.5941
# Epoch 10/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.7818 - accuracy: 0.6208
# Epoch 00010: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.7849 - accuracy: 0.6182 - val_loss: 0.8033 - val_accuracy: 0.6040
# Epoch 11/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.7634 - accuracy: 0.6178
# Epoch 00011: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 36ms/step - loss: 0.7581 - accuracy: 0.6147 - val_loss: 0.7794 - val_accuracy: 0.6040
# Epoch 12/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.7330 - accuracy: 0.6250
# Epoch 00012: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.7323 - accuracy: 0.6200 - val_loss: 0.7498 - val_accuracy: 0.6040
# Epoch 13/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.7064 - accuracy: 0.6333
# Epoch 00013: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.7040 - accuracy: 0.6287 - val_loss: 0.7254 - val_accuracy: 0.6238
# Epoch 14/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.6893 - accuracy: 0.6295
# Epoch 00014: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.6838 - accuracy: 0.6322 - val_loss: 0.7018 - val_accuracy: 0.6337
# Epoch 15/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6713 - accuracy: 0.6438
# Epoch 00015: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.6639 - accuracy: 0.6515 - val_loss: 0.6802 - val_accuracy: 0.6931
# Epoch 16/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6455 - accuracy: 0.6896
# Epoch 00016: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.6492 - accuracy: 0.7005 - val_loss: 0.6535 - val_accuracy: 0.7822
# Epoch 17/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.6341 - accuracy: 0.7344
# Epoch 00017: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.6271 - accuracy: 0.7233 - val_loss: 0.6403 - val_accuracy: 0.7723
# Epoch 18/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6246 - accuracy: 0.7333
# Epoch 00018: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.6182 - accuracy: 0.7443 - val_loss: 0.6187 - val_accuracy: 0.8416
# Epoch 19/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.6091 - accuracy: 0.7788
# Epoch 00019: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.6059 - accuracy: 0.7741 - val_loss: 0.6026 - val_accuracy: 0.8812
# Epoch 20/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6040 - accuracy: 0.7854
# Epoch 00020: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 36ms/step - loss: 0.5911 - accuracy: 0.7898 - val_loss: 0.5885 - val_accuracy: 0.8713
# Epoch 21/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5887 - accuracy: 0.7991
# Epoch 00021: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.5830 - accuracy: 0.8004 - val_loss: 0.5791 - val_accuracy: 0.8713
# Epoch 22/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5808 - accuracy: 0.7857
# Epoch 00022: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.5677 - accuracy: 0.7986 - val_loss: 0.5583 - val_accuracy: 0.8812
# Epoch 23/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5467 - accuracy: 0.8167
# Epoch 00023: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.5563 - accuracy: 0.8179 - val_loss: 0.5509 - val_accuracy: 0.8812
# Epoch 24/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5232 - accuracy: 0.8237
# Epoch 00024: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.5441 - accuracy: 0.8056 - val_loss: 0.5341 - val_accuracy: 0.8812
# Epoch 25/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5313 - accuracy: 0.8208
# Epoch 00025: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.5346 - accuracy: 0.8196 - val_loss: 0.5243 - val_accuracy: 0.8812
# Epoch 26/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5470 - accuracy: 0.8237
# Epoch 00026: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.5263 - accuracy: 0.8319 - val_loss: 0.5155 - val_accuracy: 0.8812
# Epoch 27/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5087 - accuracy: 0.8271
# Epoch 00027: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.5163 - accuracy: 0.8266 - val_loss: 0.5030 - val_accuracy: 0.8713
# Epoch 28/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.5034 - accuracy: 0.8245
# Epoch 00028: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 35ms/step - loss: 0.5059 - accuracy: 0.8301 - val_loss: 0.4991 - val_accuracy: 0.8713
# Epoch 29/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4916 - accuracy: 0.8146
# Epoch 00029: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.4953 - accuracy: 0.8231 - val_loss: 0.4835 - val_accuracy: 0.8812
# Epoch 30/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4812 - accuracy: 0.8482
# Epoch 00030: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 36ms/step - loss: 0.4878 - accuracy: 0.8494 - val_loss: 0.4828 - val_accuracy: 0.8614
# Epoch 31/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.5049 - accuracy: 0.8269
# Epoch 00031: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.4880 - accuracy: 0.8511 - val_loss: 0.4704 - val_accuracy: 0.8911
# Epoch 32/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5058 - accuracy: 0.8371
# Epoch 00032: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 42ms/step - loss: 0.4759 - accuracy: 0.8459 - val_loss: 0.4874 - val_accuracy: 0.8020
# Epoch 33/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4656 - accuracy: 0.8281
# Epoch 00033: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.4674 - accuracy: 0.8179 - val_loss: 0.4569 - val_accuracy: 0.8812
# Epoch 34/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4592 - accuracy: 0.8521
# Epoch 00034: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.4591 - accuracy: 0.8529 - val_loss: 0.4572 - val_accuracy: 0.8614
# Epoch 35/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4546 - accuracy: 0.8438
# Epoch 00035: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.4499 - accuracy: 0.8511 - val_loss: 0.4471 - val_accuracy: 0.8713
# Epoch 36/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.4409 - accuracy: 0.8678
# Epoch 00036: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 33ms/step - loss: 0.4406 - accuracy: 0.8651 - val_loss: 0.4377 - val_accuracy: 0.8713
# Epoch 37/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4359 - accuracy: 0.8683
# Epoch 00037: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.4317 - accuracy: 0.8669 - val_loss: 0.4392 - val_accuracy: 0.8515
# Epoch 38/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4455 - accuracy: 0.8661
# Epoch 00038: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.4276 - accuracy: 0.8739 - val_loss: 0.4378 - val_accuracy: 0.8713
# Epoch 39/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4157 - accuracy: 0.8638
# Epoch 00039: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 33ms/step - loss: 0.4250 - accuracy: 0.8616 - val_loss: 0.4259 - val_accuracy: 0.8614
# Epoch 40/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4346 - accuracy: 0.8571
# Epoch 00040: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.4185 - accuracy: 0.8704 - val_loss: 0.4215 - val_accuracy: 0.8713
# Epoch 41/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.4214 - accuracy: 0.8798
# Epoch 00041: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.4185 - accuracy: 0.8827 - val_loss: 0.4121 - val_accuracy: 0.8713
# Epoch 42/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3909 - accuracy: 0.8750
# Epoch 00042: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.4106 - accuracy: 0.8616 - val_loss: 0.3960 - val_accuracy: 0.8812
# Epoch 43/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4162 - accuracy: 0.8728
# Epoch 00043: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.4029 - accuracy: 0.8774 - val_loss: 0.4181 - val_accuracy: 0.8614
# Epoch 44/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3824 - accuracy: 0.8728
# Epoch 00044: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.3850 - accuracy: 0.8809 - val_loss: 0.3907 - val_accuracy: 0.8713
# Epoch 45/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3653 - accuracy: 0.8973
# Epoch 00045: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.3820 - accuracy: 0.8914 - val_loss: 0.3993 - val_accuracy: 0.8614
# Epoch 46/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3989 - accuracy: 0.8792
# Epoch 00046: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3833 - accuracy: 0.8809 - val_loss: 0.4157 - val_accuracy: 0.8911
# Epoch 47/200
# 12/18 [===================>..........] - ETA: 0s - loss: 0.3609 - accuracy: 0.8828
# Epoch 00047: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 35ms/step - loss: 0.3828 - accuracy: 0.8722 - val_loss: 0.4430 - val_accuracy: 0.8614
# Epoch 48/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3842 - accuracy: 0.8729
# Epoch 00048: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3687 - accuracy: 0.8844 - val_loss: 0.3821 - val_accuracy: 0.8713
# Epoch 49/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.3483 - accuracy: 0.8966
# Epoch 00049: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3626 - accuracy: 0.8879 - val_loss: 0.3863 - val_accuracy: 0.8614
# Epoch 50/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3775 - accuracy: 0.8813
# Epoch 00050: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3632 - accuracy: 0.8862 - val_loss: 0.3878 - val_accuracy: 0.8911
# Epoch 51/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3435 - accuracy: 0.9062
# Epoch 00051: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.3476 - accuracy: 0.9037 - val_loss: 0.3474 - val_accuracy: 0.9010
# Epoch 52/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3538 - accuracy: 0.8687
# Epoch 00052: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3498 - accuracy: 0.8792 - val_loss: 0.3545 - val_accuracy: 0.8812
# Epoch 53/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3462 - accuracy: 0.8896
# Epoch 00053: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3364 - accuracy: 0.8949 - val_loss: 0.3440 - val_accuracy: 0.8812
# Epoch 54/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3256 - accuracy: 0.8979
# Epoch 00054: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 37ms/step - loss: 0.3430 - accuracy: 0.8827 - val_loss: 0.3623 - val_accuracy: 0.8713
# Epoch 55/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3225 - accuracy: 0.9146
# Epoch 00055: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.3378 - accuracy: 0.9037 - val_loss: 0.3313 - val_accuracy: 0.9010
# Epoch 56/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3476 - accuracy: 0.8906
# Epoch 00056: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3372 - accuracy: 0.8949 - val_loss: 0.3598 - val_accuracy: 0.8911
# Epoch 57/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3027 - accuracy: 0.9104
# Epoch 00057: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3300 - accuracy: 0.8984 - val_loss: 0.3386 - val_accuracy: 0.8713
# Epoch 58/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3153 - accuracy: 0.9104
# Epoch 00058: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3136 - accuracy: 0.9089 - val_loss: 0.3471 - val_accuracy: 0.9109
# Epoch 59/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3211 - accuracy: 0.8906
# Epoch 00059: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3141 - accuracy: 0.8949 - val_loss: 0.3246 - val_accuracy: 0.9109
# Epoch 60/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3070 - accuracy: 0.8979
# Epoch 00060: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3115 - accuracy: 0.8984 - val_loss: 0.3277 - val_accuracy: 0.9010
# Epoch 61/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3044 - accuracy: 0.9018
# Epoch 00061: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3060 - accuracy: 0.8967 - val_loss: 0.3363 - val_accuracy: 0.8713
# Epoch 62/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.3155 - accuracy: 0.8938
# Epoch 00062: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.3102 - accuracy: 0.8914 - val_loss: 0.3130 - val_accuracy: 0.9109
# Epoch 63/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.3056 - accuracy: 0.9085
# Epoch 00063: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.3002 - accuracy: 0.9142 - val_loss: 0.3507 - val_accuracy: 0.8713
# Epoch 64/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2729 - accuracy: 0.9263
# Epoch 00064: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2941 - accuracy: 0.9124 - val_loss: 0.3554 - val_accuracy: 0.9208
# Epoch 65/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2693 - accuracy: 0.9167
# Epoch 00065: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2901 - accuracy: 0.9037 - val_loss: 0.3402 - val_accuracy: 0.8713
# Epoch 66/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2884 - accuracy: 0.9087
# Epoch 00066: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.2916 - accuracy: 0.9107 - val_loss: 0.3156 - val_accuracy: 0.8911
# Epoch 67/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2813 - accuracy: 0.9062
# Epoch 00067: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2877 - accuracy: 0.9159 - val_loss: 0.3232 - val_accuracy: 0.9109
# Epoch 68/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2706 - accuracy: 0.8996
# Epoch 00068: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2855 - accuracy: 0.9002 - val_loss: 0.3218 - val_accuracy: 0.9109
# Epoch 69/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2819 - accuracy: 0.9062
# Epoch 00069: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 37ms/step - loss: 0.2783 - accuracy: 0.9072 - val_loss: 0.3144 - val_accuracy: 0.9208
# Epoch 70/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2532 - accuracy: 0.9104
# Epoch 00070: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 44ms/step - loss: 0.2727 - accuracy: 0.9107 - val_loss: 0.3204 - val_accuracy: 0.9010
# Epoch 71/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2770 - accuracy: 0.9174
# Epoch 00071: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.2648 - accuracy: 0.9159 - val_loss: 0.3362 - val_accuracy: 0.9208
# Epoch 72/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2931 - accuracy: 0.9125
# Epoch 00072: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2743 - accuracy: 0.9212 - val_loss: 0.3453 - val_accuracy: 0.9109
# Epoch 73/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2514 - accuracy: 0.9174
# Epoch 00073: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2659 - accuracy: 0.9124 - val_loss: 0.3302 - val_accuracy: 0.9208
# Epoch 74/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2709 - accuracy: 0.9062
# Epoch 00074: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2662 - accuracy: 0.9072 - val_loss: 0.3336 - val_accuracy: 0.9307
# Epoch 75/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2705 - accuracy: 0.9014
# Epoch 00075: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2748 - accuracy: 0.9089 - val_loss: 0.2797 - val_accuracy: 0.9010
# Epoch 76/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2288 - accuracy: 0.9231
# Epoch 00076: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 37ms/step - loss: 0.2690 - accuracy: 0.9107 - val_loss: 0.2892 - val_accuracy: 0.9109
# Epoch 77/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2659 - accuracy: 0.9107
# Epoch 00077: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2632 - accuracy: 0.9037 - val_loss: 0.3250 - val_accuracy: 0.9109
# Epoch 78/200
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2527 - accuracy: 0.9136
# Epoch 00078: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 39ms/step - loss: 0.2555 - accuracy: 0.9124 - val_loss: 0.2839 - val_accuracy: 0.9307
# Epoch 79/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2446 - accuracy: 0.9014
# Epoch 00079: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.2519 - accuracy: 0.9089 - val_loss: 0.2873 - val_accuracy: 0.8812
# Epoch 80/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2297 - accuracy: 0.9241
# Epoch 00080: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2486 - accuracy: 0.9159 - val_loss: 0.2869 - val_accuracy: 0.9208
# Epoch 81/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2376 - accuracy: 0.9208
# Epoch 00081: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.2398 - accuracy: 0.9177 - val_loss: 0.3065 - val_accuracy: 0.9109
# Epoch 82/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2271 - accuracy: 0.9308
# Epoch 00082: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2395 - accuracy: 0.9194 - val_loss: 0.3084 - val_accuracy: 0.9208
# Epoch 83/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2566 - accuracy: 0.9129
# Epoch 00083: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2396 - accuracy: 0.9194 - val_loss: 0.2813 - val_accuracy: 0.9208
# Epoch 84/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2235 - accuracy: 0.9286
# Epoch 00084: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2367 - accuracy: 0.9194 - val_loss: 0.2969 - val_accuracy: 0.9208
# Epoch 85/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2576 - accuracy: 0.9152
# Epoch 00085: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2443 - accuracy: 0.9177 - val_loss: 0.3225 - val_accuracy: 0.9109
# Epoch 86/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2435 - accuracy: 0.9196
# Epoch 00086: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.2461 - accuracy: 0.9142 - val_loss: 0.3054 - val_accuracy: 0.9208
# Epoch 87/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2263 - accuracy: 0.9219
# Epoch 00087: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2374 - accuracy: 0.9159 - val_loss: 0.3177 - val_accuracy: 0.9406
# Epoch 88/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2188 - accuracy: 0.9308
# Epoch 00088: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 39ms/step - loss: 0.2341 - accuracy: 0.9247 - val_loss: 0.3385 - val_accuracy: 0.9208
# Epoch 89/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2693 - accuracy: 0.9085
# Epoch 00089: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2583 - accuracy: 0.9089 - val_loss: 0.3112 - val_accuracy: 0.9406
# Epoch 90/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2479 - accuracy: 0.9107
# Epoch 00090: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2394 - accuracy: 0.9159 - val_loss: 0.3663 - val_accuracy: 0.8911
# Epoch 91/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2398 - accuracy: 0.9107
# Epoch 00091: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.2296 - accuracy: 0.9159 - val_loss: 0.3001 - val_accuracy: 0.9307
# Epoch 92/200
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2293 - accuracy: 0.9191
# Epoch 00092: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2237 - accuracy: 0.9212 - val_loss: 0.2878 - val_accuracy: 0.9406
# Epoch 93/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2219 - accuracy: 0.9229
# Epoch 00093: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.2264 - accuracy: 0.9229 - val_loss: 0.2678 - val_accuracy: 0.9307
# Epoch 94/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2175 - accuracy: 0.9250
# Epoch 00094: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2195 - accuracy: 0.9212 - val_loss: 0.2513 - val_accuracy: 0.9109
# Epoch 95/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2002 - accuracy: 0.9351
# Epoch 00095: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.2253 - accuracy: 0.9229 - val_loss: 0.2755 - val_accuracy: 0.9406
# Epoch 96/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2143 - accuracy: 0.9333
# Epoch 00096: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2176 - accuracy: 0.9282 - val_loss: 0.2817 - val_accuracy: 0.9208
# Epoch 97/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2246 - accuracy: 0.9292
# Epoch 00097: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 28ms/step - loss: 0.2195 - accuracy: 0.9282 - val_loss: 0.3092 - val_accuracy: 0.9307
# Epoch 98/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2087 - accuracy: 0.9312
# Epoch 00098: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 38ms/step - loss: 0.2146 - accuracy: 0.9264 - val_loss: 0.2451 - val_accuracy: 0.9109
# Epoch 99/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2439 - accuracy: 0.9038
# Epoch 00099: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2182 - accuracy: 0.9247 - val_loss: 0.2584 - val_accuracy: 0.9109
# Epoch 100/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1888 - accuracy: 0.9312
# Epoch 00100: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.2062 - accuracy: 0.9264 - val_loss: 0.2721 - val_accuracy: 0.9307
# Epoch 101/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2042 - accuracy: 0.9330
# Epoch 00101: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.2035 - accuracy: 0.9352 - val_loss: 0.2790 - val_accuracy: 0.9307
# Epoch 102/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2108 - accuracy: 0.9303
# Epoch 00102: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.2184 - accuracy: 0.9229 - val_loss: 0.2681 - val_accuracy: 0.9307
# Epoch 103/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2085 - accuracy: 0.9241
# Epoch 00103: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2030 - accuracy: 0.9282 - val_loss: 0.3313 - val_accuracy: 0.9406
# Epoch 104/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1990 - accuracy: 0.9255
# Epoch 00104: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2025 - accuracy: 0.9247 - val_loss: 0.2610 - val_accuracy: 0.9307
# Epoch 105/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1991 - accuracy: 0.9271
# Epoch 00105: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.2002 - accuracy: 0.9247 - val_loss: 0.2903 - val_accuracy: 0.9307
# Epoch 106/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2087 - accuracy: 0.9174
# Epoch 00106: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 38ms/step - loss: 0.2070 - accuracy: 0.9194 - val_loss: 0.2854 - val_accuracy: 0.9307
# Epoch 107/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2004 - accuracy: 0.9271
# Epoch 00107: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1996 - accuracy: 0.9282 - val_loss: 0.2761 - val_accuracy: 0.9406
# Epoch 108/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1954 - accuracy: 0.9286
# Epoch 00108: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2028 - accuracy: 0.9299 - val_loss: 0.2786 - val_accuracy: 0.9109
# Epoch 109/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1934 - accuracy: 0.9263
# Epoch 00109: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1997 - accuracy: 0.9282 - val_loss: 0.2721 - val_accuracy: 0.9406
# Epoch 110/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1749 - accuracy: 0.9487
# Epoch 00110: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1970 - accuracy: 0.9370 - val_loss: 0.2709 - val_accuracy: 0.9307
# Epoch 111/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1953 - accuracy: 0.9255
# Epoch 00111: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1916 - accuracy: 0.9264 - val_loss: 0.2646 - val_accuracy: 0.9406
# Epoch 112/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1712 - accuracy: 0.9509
# Epoch 00112: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1861 - accuracy: 0.9440 - val_loss: 0.2767 - val_accuracy: 0.9406
# Epoch 113/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1882 - accuracy: 0.9375
# Epoch 00113: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.2014 - accuracy: 0.9335 - val_loss: 0.2642 - val_accuracy: 0.9307
# Epoch 114/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2167 - accuracy: 0.9207
# Epoch 00114: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.2050 - accuracy: 0.9264 - val_loss: 0.3582 - val_accuracy: 0.9208
# Epoch 115/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2111 - accuracy: 0.9241
# Epoch 00115: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.2020 - accuracy: 0.9282 - val_loss: 0.2577 - val_accuracy: 0.9208
# Epoch 116/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2098 - accuracy: 0.9333
# Epoch 00116: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1980 - accuracy: 0.9352 - val_loss: 0.2567 - val_accuracy: 0.9406
# Epoch 117/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1927 - accuracy: 0.9354
# Epoch 00117: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1951 - accuracy: 0.9317 - val_loss: 0.2584 - val_accuracy: 0.9406
# Epoch 118/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1763 - accuracy: 0.9312
# Epoch 00118: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 39ms/step - loss: 0.1870 - accuracy: 0.9264 - val_loss: 0.2173 - val_accuracy: 0.9406
# Epoch 119/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1981 - accuracy: 0.9417
# Epoch 00119: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1887 - accuracy: 0.9440 - val_loss: 0.2591 - val_accuracy: 0.9307
# Epoch 120/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1765 - accuracy: 0.9330
# Epoch 00120: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 38ms/step - loss: 0.1899 - accuracy: 0.9282 - val_loss: 0.2286 - val_accuracy: 0.9109
# Epoch 121/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1698 - accuracy: 0.9396
# Epoch 00121: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1782 - accuracy: 0.9335 - val_loss: 0.2506 - val_accuracy: 0.9406
# Epoch 122/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2012 - accuracy: 0.9241
# Epoch 00122: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1836 - accuracy: 0.9335 - val_loss: 0.2291 - val_accuracy: 0.9406
# Epoch 123/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1859 - accuracy: 0.9353
# Epoch 00123: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.1854 - accuracy: 0.9370 - val_loss: 0.2366 - val_accuracy: 0.9208
# Epoch 124/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1771 - accuracy: 0.9353
# Epoch 00124: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1887 - accuracy: 0.9370 - val_loss: 0.2504 - val_accuracy: 0.9406
# Epoch 125/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1526 - accuracy: 0.9442
# Epoch 00125: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1765 - accuracy: 0.9405 - val_loss: 0.2183 - val_accuracy: 0.9109
# Epoch 126/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1639 - accuracy: 0.9420
# Epoch 00126: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1827 - accuracy: 0.9317 - val_loss: 0.2685 - val_accuracy: 0.9406
# Epoch 127/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1682 - accuracy: 0.9479
# Epoch 00127: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1762 - accuracy: 0.9422 - val_loss: 0.2440 - val_accuracy: 0.9406
# Epoch 128/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1845 - accuracy: 0.9263
# Epoch 00128: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1867 - accuracy: 0.9229 - val_loss: 0.2880 - val_accuracy: 0.9307
# Epoch 129/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1866 - accuracy: 0.9333
# Epoch 00129: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.1780 - accuracy: 0.9352 - val_loss: 0.3311 - val_accuracy: 0.9307
# Epoch 130/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1888 - accuracy: 0.9229
# Epoch 00130: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1807 - accuracy: 0.9282 - val_loss: 0.2625 - val_accuracy: 0.9406
# Epoch 131/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1656 - accuracy: 0.9312
# Epoch 00131: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1708 - accuracy: 0.9299 - val_loss: 0.2553 - val_accuracy: 0.9307
# Epoch 132/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1823 - accuracy: 0.9354
# Epoch 00132: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1725 - accuracy: 0.9387 - val_loss: 0.2540 - val_accuracy: 0.9109
# Epoch 133/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1788 - accuracy: 0.9354
# Epoch 00133: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1815 - accuracy: 0.9299 - val_loss: 0.2708 - val_accuracy: 0.9406
# Epoch 134/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1584 - accuracy: 0.9375
# Epoch 00134: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1714 - accuracy: 0.9299 - val_loss: 0.2680 - val_accuracy: 0.9307
# Epoch 135/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1605 - accuracy: 0.9354
# Epoch 00135: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1676 - accuracy: 0.9335 - val_loss: 0.2798 - val_accuracy: 0.9208
# Epoch 136/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1696 - accuracy: 0.9396
# Epoch 00136: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 46ms/step - loss: 0.1757 - accuracy: 0.9370 - val_loss: 0.3007 - val_accuracy: 0.9406
# Epoch 137/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1617 - accuracy: 0.9458
# Epoch 00137: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1590 - accuracy: 0.9422 - val_loss: 0.2784 - val_accuracy: 0.9307
# Epoch 138/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1605 - accuracy: 0.9500
# Epoch 00138: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1702 - accuracy: 0.9422 - val_loss: 0.2782 - val_accuracy: 0.9109
# Epoch 139/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1728 - accuracy: 0.9396
# Epoch 00139: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1767 - accuracy: 0.9352 - val_loss: 0.3238 - val_accuracy: 0.9307
# Epoch 140/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1694 - accuracy: 0.9333
# Epoch 00140: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 28ms/step - loss: 0.1724 - accuracy: 0.9370 - val_loss: 0.3242 - val_accuracy: 0.9307
# Epoch 141/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1694 - accuracy: 0.9375
# Epoch 00141: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1668 - accuracy: 0.9370 - val_loss: 0.2840 - val_accuracy: 0.9307
# Epoch 142/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1839 - accuracy: 0.9271
# Epoch 00142: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1770 - accuracy: 0.9282 - val_loss: 0.2790 - val_accuracy: 0.9406
# Epoch 143/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1756 - accuracy: 0.9330
# Epoch 00143: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1664 - accuracy: 0.9387 - val_loss: 0.2961 - val_accuracy: 0.9307
# Epoch 144/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1615 - accuracy: 0.9396
# Epoch 00144: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1635 - accuracy: 0.9370 - val_loss: 0.2916 - val_accuracy: 0.9208
# Epoch 145/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1771 - accuracy: 0.9375
# Epoch 00145: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1666 - accuracy: 0.9422 - val_loss: 0.3394 - val_accuracy: 0.9406
# Epoch 146/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1510 - accuracy: 0.9442
# Epoch 00146: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1629 - accuracy: 0.9370 - val_loss: 0.3344 - val_accuracy: 0.9406
# Epoch 147/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1522 - accuracy: 0.9464
# Epoch 00147: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 43ms/step - loss: 0.1540 - accuracy: 0.9440 - val_loss: 0.2596 - val_accuracy: 0.9307
# Epoch 148/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1428 - accuracy: 0.9521
# Epoch 00148: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1579 - accuracy: 0.9457 - val_loss: 0.2667 - val_accuracy: 0.9109
# Epoch 149/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1575 - accuracy: 0.9354
# Epoch 00149: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1576 - accuracy: 0.9387 - val_loss: 0.2694 - val_accuracy: 0.9208
# Epoch 150/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1517 - accuracy: 0.9479
# Epoch 00150: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1570 - accuracy: 0.9422 - val_loss: 0.3178 - val_accuracy: 0.9307
# Epoch 151/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1586 - accuracy: 0.9417
# Epoch 00151: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1616 - accuracy: 0.9405 - val_loss: 0.2941 - val_accuracy: 0.9307
# Epoch 152/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1399 - accuracy: 0.9509
# Epoch 00152: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1577 - accuracy: 0.9387 - val_loss: 0.2745 - val_accuracy: 0.9307
# Epoch 153/200
# 16/18 [=========================>....] - ETA: 0s - loss: 0.1604 - accuracy: 0.9434
# Epoch 00153: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1528 - accuracy: 0.9492 - val_loss: 0.2776 - val_accuracy: 0.9109
# Epoch 154/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1584 - accuracy: 0.9399
# Epoch 00154: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1503 - accuracy: 0.9440 - val_loss: 0.3133 - val_accuracy: 0.9406
# Epoch 155/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1449 - accuracy: 0.9487
# Epoch 00155: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1489 - accuracy: 0.9475 - val_loss: 0.2758 - val_accuracy: 0.9208
# Epoch 156/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1561 - accuracy: 0.9397
# Epoch 00156: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1564 - accuracy: 0.9387 - val_loss: 0.2778 - val_accuracy: 0.9307
# Epoch 157/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1637 - accuracy: 0.9351
# Epoch 00157: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1505 - accuracy: 0.9405 - val_loss: 0.2171 - val_accuracy: 0.9208
# Epoch 158/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1381 - accuracy: 0.9442
# Epoch 00158: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1420 - accuracy: 0.9422 - val_loss: 0.2789 - val_accuracy: 0.9307
# Epoch 159/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1591 - accuracy: 0.9464
# Epoch 00159: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1414 - accuracy: 0.9545 - val_loss: 0.2849 - val_accuracy: 0.9406
# Epoch 160/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1409 - accuracy: 0.9621
# Epoch 00160: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1476 - accuracy: 0.9527 - val_loss: 0.3074 - val_accuracy: 0.9406
# Epoch 161/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1645 - accuracy: 0.9375
# Epoch 00161: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1518 - accuracy: 0.9440 - val_loss: 0.3451 - val_accuracy: 0.9307
# Epoch 162/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1404 - accuracy: 0.9500
# Epoch 00162: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1415 - accuracy: 0.9527 - val_loss: 0.2901 - val_accuracy: 0.9307
# Epoch 163/200
# 18/18 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9510
# Epoch 00163: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 35ms/step - loss: 0.1466 - accuracy: 0.9510 - val_loss: 0.4366 - val_accuracy: 0.9406
# Epoch 164/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1595 - accuracy: 0.9458
# Epoch 00164: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1714 - accuracy: 0.9440 - val_loss: 0.1849 - val_accuracy: 0.9505
# Epoch 165/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1749 - accuracy: 0.9438
# Epoch 00165: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.1730 - accuracy: 0.9422 - val_loss: 0.2040 - val_accuracy: 0.9307
# Epoch 166/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1628 - accuracy: 0.9375
# Epoch 00166: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1524 - accuracy: 0.9387 - val_loss: 0.1939 - val_accuracy: 0.9307
# Epoch 167/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1581 - accuracy: 0.9396
# Epoch 00167: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1473 - accuracy: 0.9457 - val_loss: 0.2409 - val_accuracy: 0.9307
# Epoch 168/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1295 - accuracy: 0.9487
# Epoch 00168: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1424 - accuracy: 0.9475 - val_loss: 0.2060 - val_accuracy: 0.9208
# Epoch 169/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1416 - accuracy: 0.9542
# Epoch 00169: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1371 - accuracy: 0.9580 - val_loss: 0.2158 - val_accuracy: 0.9406
# Epoch 170/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1390 - accuracy: 0.9521
# Epoch 00170: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1392 - accuracy: 0.9527 - val_loss: 0.1914 - val_accuracy: 0.9307
# Epoch 171/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1738 - accuracy: 0.9308
# Epoch 00171: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1503 - accuracy: 0.9405 - val_loss: 0.1897 - val_accuracy: 0.9307
# Epoch 172/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1629 - accuracy: 0.9479
# Epoch 00172: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1561 - accuracy: 0.9492 - val_loss: 0.2048 - val_accuracy: 0.9208
# Epoch 173/200
# 18/18 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9475
# Epoch 00173: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1397 - accuracy: 0.9475 - val_loss: 0.2060 - val_accuracy: 0.9208
# Epoch 174/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1363 - accuracy: 0.9519
# Epoch 00174: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 38ms/step - loss: 0.1395 - accuracy: 0.9457 - val_loss: 0.2181 - val_accuracy: 0.9406
# Epoch 175/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1328 - accuracy: 0.9500
# Epoch 00175: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1378 - accuracy: 0.9510 - val_loss: 0.1824 - val_accuracy: 0.9307
# Epoch 176/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1442 - accuracy: 0.9447
# Epoch 00176: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1401 - accuracy: 0.9475 - val_loss: 0.1767 - val_accuracy: 0.9505
# Epoch 177/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1332 - accuracy: 0.9531
# Epoch 00177: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1291 - accuracy: 0.9580 - val_loss: 0.2063 - val_accuracy: 0.9208
# Epoch 178/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1355 - accuracy: 0.9554
# Epoch 00178: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.1303 - accuracy: 0.9562 - val_loss: 0.1982 - val_accuracy: 0.9307
# Epoch 179/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1362 - accuracy: 0.9464
# Epoch 00179: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1321 - accuracy: 0.9492 - val_loss: 0.1920 - val_accuracy: 0.9307
# Epoch 180/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1609 - accuracy: 0.9447
# Epoch 00180: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1368 - accuracy: 0.9545 - val_loss: 0.1804 - val_accuracy: 0.9307
# Epoch 181/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1434 - accuracy: 0.9521
# Epoch 00181: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 28ms/step - loss: 0.1386 - accuracy: 0.9510 - val_loss: 0.2058 - val_accuracy: 0.9307
# Epoch 182/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1550 - accuracy: 0.9399
# Epoch 00182: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1372 - accuracy: 0.9457 - val_loss: 0.1877 - val_accuracy: 0.9307
# Epoch 183/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1440 - accuracy: 0.9471
# Epoch 00183: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1306 - accuracy: 0.9510 - val_loss: 0.2295 - val_accuracy: 0.9307
# Epoch 184/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1324 - accuracy: 0.9479
# Epoch 00184: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.1309 - accuracy: 0.9527 - val_loss: 0.2112 - val_accuracy: 0.9406
# Epoch 185/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1358 - accuracy: 0.9563
# Epoch 00185: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 44ms/step - loss: 0.1331 - accuracy: 0.9580 - val_loss: 0.1806 - val_accuracy: 0.9307
# Epoch 186/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1421 - accuracy: 0.9567
# Epoch 00186: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1308 - accuracy: 0.9562 - val_loss: 0.1951 - val_accuracy: 0.9307
# Epoch 187/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1156 - accuracy: 0.9621
# Epoch 00187: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1301 - accuracy: 0.9527 - val_loss: 0.2026 - val_accuracy: 0.9307
# Epoch 188/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1267 - accuracy: 0.9663
# Epoch 00188: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.1270 - accuracy: 0.9615 - val_loss: 0.2044 - val_accuracy: 0.9505
# Epoch 189/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1146 - accuracy: 0.9598
# Epoch 00189: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1305 - accuracy: 0.9527 - val_loss: 0.1881 - val_accuracy: 0.9208
# Epoch 190/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1393 - accuracy: 0.9438
# Epoch 00190: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 25ms/step - loss: 0.1300 - accuracy: 0.9492 - val_loss: 0.2149 - val_accuracy: 0.9406
# Epoch 191/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1278 - accuracy: 0.9583
# Epoch 00191: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1273 - accuracy: 0.9580 - val_loss: 0.2041 - val_accuracy: 0.9307
# Epoch 192/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1346 - accuracy: 0.9464
# Epoch 00192: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1265 - accuracy: 0.9527 - val_loss: 0.2058 - val_accuracy: 0.9307
# Epoch 193/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1106 - accuracy: 0.9598
# Epoch 00193: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1250 - accuracy: 0.9580 - val_loss: 0.2059 - val_accuracy: 0.9307
# Epoch 194/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1280 - accuracy: 0.9576
# Epoch 00194: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 38ms/step - loss: 0.1268 - accuracy: 0.9580 - val_loss: 0.1819 - val_accuracy: 0.9307
# Epoch 195/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1365 - accuracy: 0.9567
# Epoch 00195: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.1302 - accuracy: 0.9545 - val_loss: 0.1983 - val_accuracy: 0.9406
# Epoch 196/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1294 - accuracy: 0.9542
# Epoch 00196: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1258 - accuracy: 0.9545 - val_loss: 0.1902 - val_accuracy: 0.9406
# Epoch 197/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1322 - accuracy: 0.9521
# Epoch 00197: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1271 - accuracy: 0.9545 - val_loss: 0.1868 - val_accuracy: 0.9406
# Epoch 198/200
# 15/18 [========================>.....] - ETA: 0s - loss: 0.1199 - accuracy: 0.9542
# Epoch 00198: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1243 - accuracy: 0.9580 - val_loss: 0.1951 - val_accuracy: 0.9307
# Epoch 199/200
# 14/18 [======================>.......] - ETA: 0s - loss: 0.1243 - accuracy: 0.9598
# Epoch 00199: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1215 - accuracy: 0.9597 - val_loss: 0.1865 - val_accuracy: 0.9406
# Epoch 200/200
# 13/18 [====================>.........] - ETA: 0s - loss: 0.1255 - accuracy: 0.9639
# Epoch 00200: saving model to ./model\model_imu_cnn1d_rawData.h5
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1293 - accuracy: 0.9562 - val_loss: 0.2060 - val_accuracy: 0.9406
#
# Average iteration time: 11.04 ms
# Average epoch time: 0.20 s
# Total training time: 39.75 s

# %%
#Getting the accuracy
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

#Getting the losses
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plotting Training and Validation accuracy
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, '-', label='Training Accuracy', linewidth=2.5)
plt.plot(epochs, val_acc, '-', label='Validation Accuracy', linewidth=2.5)
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, '-', label='Training Loss', linewidth=2.5)
plt.plot(epochs, val_loss, '-', label='Validation Loss', linewidth=2.5)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
model = load_model('./model/model_imu_cnn1d_rawData.h5')
score_val = model.evaluate(X_val, y_val, verbose = 0) 
print('Val loss:', score_val[0]) 
print('Val accuracy:', score_val[1])
# Out:
# Val loss: 0.20601356029510498
# Val accuracy: 0.9405940771102905

# %%
# Predict validation data
class_labels = ["Minor_Crash", "Normal", "Severe_Crash"]

sns.set()
val_predicted = model.predict(X_val)
y_val = y_val.argmax(axis=1)
y_val_predict = val_predicted.argmax(axis=1)
mat = confusion_matrix(y_val, y_val_predict)
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=True, cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.title('Confusion Matrix for Validation Data')
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
# Out:
# Text(74.30937500000006, 0.5, 'Actual label')

# %%
print(classification_report(y_val, y_val_predict, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  Minor_Crash       0.89      0.97      0.93        32
#       Normal       0.95      0.97      0.96        38
# Severe_Crash       1.00      0.87      0.93        31
#
#     accuracy                           0.94       101
#    macro avg       0.94      0.94      0.94       101
# weighted avg       0.94      0.94      0.94       101
